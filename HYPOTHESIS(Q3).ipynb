# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheerajthummala/hypothesis_test/blob/main/HYPOTHESIS(Q3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
buyer=pd.read_csv('BuyerRatio.csv')

# %%
#Ho=all proportion are equal
#Ha=not all proportion are equal

# %%
buyer.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
buyerratio=buyer.iloc[:,1:5]
buyerratio
# Out:
#    East  West  North  South
# 0    50   142    131     70
# 1   435  1523   1356    750

# %%
buyerratio.values
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
exp=stats.chi2_contingency(buyerratio)
exp
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
observed = np.array([50, 142, 131, 70, 435, 1523, 1356, 750])
expected = np.array([42.76531299,  146.81287862,  131.11756787, 72.30424052, 442.23468701, 1518.18712138, 1355.88243213,  747.69575948])

# %%
#now finding p value using chisquare
statistics, p_value = stats.chisquare(observed, expected, 3)
p_value
# Out:
# 0.8095206646905712

# %%
#as per qst singinificance level=0.05
# p value is greater than significance level

# %%
# so, we fail to reject null hypothesis
